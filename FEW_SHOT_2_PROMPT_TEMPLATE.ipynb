# %% [markdown]
# <a href="https://colab.research.google.com/github/babatundeibukun/Moderating_deliberations_with_LLMs/blob/main/FEW_SHOT_2_PROMPT_TEMPLATE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install --upgrade openai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 365.7/365.7 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 1.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 4.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.9/318.9 kB 14.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 2.9 MB/s eta 0:00:00
# ...

# %%
from openai import OpenAI
import os
model = 'gpt-4o'
client = OpenAI(api_key=os.environ.get("OPENAI_API_KEY", "API-KEY"))

# %%
def extract_points_find_clusters_and_analyze_arguments(theme, text):
    global MODEL  # Declare MODEL as a global variable
    MODEL =model  # Assign the value of model to MODEL

# %%
  MODEL = model

# %%
def analyze_and_classify(theme, text, question):
    # Step 1: Prepare the prompt for extracting points and clustering
    prompt_analysis = f"""
    -WHEN SPLITTING IS DONE:
    -NOTE: USE THE EXAMPLE BELOW TO CORRECTLY SPLIT BASED ON THE QUESTION AND TEXT PROVIDED .

    Question: {question}


    Here is the input text related to the theme '{theme}':
    {text}

    Example of correctly splitted text:

    -Question: What are the biggest challenges to UM6P achieving success in the area of research?

    -Contributions to the Question made by users during the conversation:
    User A said :
    Not enough highly qualified students to assist research.

    Students, if qualified, can radically speed up research. Yes, there are really few qualified students and postdocs. Agreed. The best students either choose industry (Computer Science) or go overseas. Be strict and make the right plans from the start and, most importantly, avoid the piston stroke and slow it down if they are not qualified, or if there are too few, very difficult to find good students with good basic training.

    User B said :

    Research should be implemented by researchers, not students. The researcher must assist students but not the contrary. Make the choice of highly motivated ambitious students in the recruitment stage and motivate them more. From a student perspective, the problem is access. The Lydex experience shows this fact. I think that UM6P students are quite intelligent given the barriers to being admitted to UM6P. Therefore, if there is a student not qualified, that means that the student didn’t have access to that field of information to be qualified.

    The prospective answers are broken down in a meaningful form as we have it below. The sentences are broken down in the original form of the user. Your task is to identify the correct answers and correct arguments for or against the answer.

    -The correct spliting of users' contributions into meaningful sentences:
    A1: Not enough highly qualified students to assist research.
    A2: Students, if qualified, can radically speed up research. Yes, there are really few qualified students and postdocs. Agreed. The best students either choose industry (Computer Science) or go overseas.
    A3: Research should be implemented by researchers, not students. The researcher must assist students but not the contrary.
    A4: Make the choice of highly motivated ambitious students in the recruitment stage and motivate them more.
    A5: From a student perspective, the problem is access.
    A6: The Lydex experience shows this fact. I think that UM6P students are quite intelligent given the barriers to being admitted to UM6P. Therefore, if there is a student not qualified, that means that the student didn’t have access to that field of information to be qualified.

    OR
    Example of correctly splitted text:
    -Question: Barriers to success in teaching/student life?

    -Contributions to the Question made by users during the conversation:

    One author said that one barrier is the lack of opportunities for students to have social interactions and activities in the region.

    Another author said that the volunteering program SEP provides social interaction opportunities for students. The availability of the volunteering program is important. There is a program encouraging volunteering among UM6P students, to work with associations, and do some social work. The initiative is called SEP. We count today more than 40 students who participated. Another point is that the lack of opportunity is a chance for creation; communication is key. The absence of an opportunity is an opportunity in itself to be created. UM6P offers many opportunities to students. There are departments whose activity is to help students launch clubs, social initiatives, and start-ups. So maybe this is a lack of communication challenge rather than an absence of opportunities.

    -The correct splitting of users' contributions into meaningful sentences:
    A1: One author said that one barrier is the lack of opportunities for students to have social interactions and activities in the region.
    A2: Another author said that the volunteering program SEP provides social interaction opportunities for students.
    A3: There is a program encouraging volunteering among UM6P students, to work with associations, and do some social work. The initiative is called SEP. We count today more than 40 students who participated.
    A4: Another point is that the lack of opportunity is a chance for creation; communication is key.
    A5: The absence of an opportunity is an opportunity in itself to be created. UM6P offers many opportunities to students.
    A6: There are departments whose activity is to help students launch clubs, social initiatives, and start-ups. So maybe this is a lack of communication challenge rather than an absence of opportunities.

    OR
    Example of correctly splitted text:other example:
    -Question:What are the best ways to measure UM6P's success in the area of research?

    -Contributions to the Question made by users during the conversation:

    User A said :

    Management, ie, the researcher must supervise the students. Without good supervision, the student cannot follow the right paths, supervision is critical in training future researchers. The supervisor must be in the field .The number of supervised students and the quality of the research output should be assessed .

    User B said :

    The supervision depends on the student, his will and his motivation, a supervisor,first of all must be a psychologically stable person with an open mind. the strength of our supervision showcases the ability to transfer knowledge to future researchers and also ensure purpetuity   -A student will do his best if he wants with light supervision, A student will do his minimum if he wants even with forced supervision.

    -The correct splitting of users' contributions into meaningful sentences:
    A1: Management, ie, the researcher must supervise the students.
    A2: Without good supervision, the student cannot follow the right paths, supervision is critical in training future researchers.
    A3: The supervision depends on the student, his will and his motivation, a supervisor,first of all must be a psychologically stable person with an open mind. the strength of our supervision showcases the ability to transfer knowledge to future researchers and also ensure purpetuity
    A4: The supervisor must be in the field.
    A5: The number of supervised students and the quality of the research output should be assessed .
    A6: A student will do his best if he wants with light supervision, A student will do his minimum if he wants even with forced supervision.
    start-ups. So maybe this is a lack of communication challenge rather than an absence of opportunities.\

    OR
     of correctly splitted text:
    -Question:What are the biggest challenges to UM6P achieving success in the area of research?

    -Contributions to the Question made by users during the conversation:
    User A said :

    Scientific/Financial/Hiring. Examples: to hire interns, a professor should not need to go through a lengthy process with HR. Paying small fees for conference registrations requires a lengthy process with Finance.
    This will help to match the project with the right person in time without delay due to HR procedures.

    -The correct splitting of users' contributions into meaningful sentences:
    A1: Scientific/Financial/Hiring. Examples: to hire interns, a professor should not need to go through a lengthy process with HR.
    A2: This will help to match the project with the right person in time without delay due to HR procedures.
    A3: Paying small fees for conference registrations requires a lengthy process with Finance.

    OR
    Example of correctly splitted text:
    -Question:What are our pain points?

    -Contributions to the Question made by users during the conversation:
    User A said :

      There is need for specialization


    User B said :

      I don't think it is a good thing, allow student to explore and be a tool for many jobs.

    -The correct splitting of users' contributions into meaningful sentences:
    A1: There is need for specialization
    A2: I don't think it is a good thing, allow student to explore and be a tool for many jobs.

    THEN

    Note: The answers and arguments are not summarized from the user's text; the original sentences are not changed or summarized.
    Further explanation:
    - There might be none, a single, or multiple answers in the text.
    - Do not repeat the example, the question, or the user's conversations in the output.
    - Do not modify any part of the text.
    """

    # Step 2: Get the response from the GPT model for extracting points
    response_analysis = client.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": "You are a smart social conversation tool. Your role is to identify the correct answers and arguments to each answer,  based on the question without changing the sentence's original form. Do not add or remove from the original texts."},
            {"role": "user", "content": prompt_analysis},
        ],
        max_tokens=1024,
        temperature=0,
        top_p=1.0,
        frequency_penalty=0,
        presence_penalty=0
    )

    # Step 3: Extract feedback
    feedback = response_analysis.choices[0].message.content.strip().split('\n')

    # Step 4: Prepare the prompt for verifying and classifying answers and arguments
    answers = '\n'.join(feedback)
    prompt_classification = f"""
    THEN CHOOSE THE CORRECT ANSWERS AND THEIR ARGUMENTS BASED ON THE EXAMPLES PROVIDED.
    -NOTE: USE THE FORMAT OF THE EXAMPLES TO CHOSE THE CORRECT ANSWERS, ARGUMENTS BASED ON THE QUESTION AND TEXT PROVIDED.
    -DO NOT EXPLAIN ANSWERS OR ARGUMENTS.
    -DO NOT SUMMARIZE THE ANSWERS OR ARGUMENTS.
    -NOTE: DO NOT REPRINT THE EXAMPLES SHOWN BELOW,

    Question: {question}
    Answers:{answers}
    Here is the input text related to the theme '{theme}':
    {text}

    OR
    -Example of correctly selected answer or answers for the Question  and their arguments which can FOR or AGAINST the chosen answer:

    A1: Not enough highly qualified students to assist research [correct is Answer1]
    A2: Students, if qualified, can radically speed up research. Yes, there are really few qualified students and postdocs Agreed. The best students either choose industry (Computer Science) or go overseas.[Argument FOR Answer1]
    A3: Research should be implemented by researcher not students, the researcher must assist student but not the contrary.[Argument AGAINST Answer1]
    A4: Make the choice of highly motivated ambitious students in the recruitment stage and motivate them more[Argument AGAINST Answer1]
    A5: From a student perspective the problem is access [correct is Answer2]
    A5: The Lydex experience shows this fact I think that UM6P students are quite intelligent given the barriers to being admitted to UM6P. therefore if there is a student not qualified that means that the student didn’t have access to that field of information to be qualified.[Argument AGAINST Answer2]

    OR
    -Example of correctly selected answer or answers for the Question  and their arguments which can FOR or AGAINST the chosen answer

    A1: Management, ie, the researcher must supervise the students. [correct is Answer1]
    A2: Without good supervision, the student cannot follow the right paths, supervision is critical in training future researchers. [Argument FOR Answer1]
    A3: The supervision depends on the student, his will and his motivation, a supervisor,first of all must be a psychologically stable person with an open mind. the strength of our supervision showcases the ability to transfer knowledge to future researchers and also ensure purpetuity   [Argument AGAINST Answer1]
    A4: The supervisor must be in the field. [Argument FOR Answer1]
    A5: The number of supervised students and the quality of the research output should be assessed. [correct is Answer2]
    A6: A student will do his best if he wants with light supervision, A student will do his minimum if he wants even with forced supervision. [Argument FOR Answer2]

    OR
    -Example of correctly selected answer or answers for the Question  and their arguments which can FOR or AGAINST the chosen answer

    A1:  Scientific/Financial/Hiring. Examples: to hire interns, a professor should not need to go through a lengthy process with HR. [correct is Answer1]
    A2: This will help to match the project with the right person in time without delay due to HR procedures. [Argument FOR Answer1]
    A3: Paying small fees for conference registrations requires a lengthy process with Finance.[Argument FOR Answer1]

    OR
    -Example of correctly selected answer or answers for the Question  and their arguments which can FOR or AGAINST the chosen answer

    A1: There is need for specialization [correct is Answer1]
    A2: I don't think it is a good thing, allow student to explore and be a tool for many jobs. [Argument AGAINST Answer1]

    OR
    -Example of correctly selected answer or answers for the Question  and their arguments which can FOR or AGAINST the chosen answer:

    A1: One author said that one barrier is lack of opportunities for students to have social interactions and activities in the region.[correct is Answer1]
    A2: Another author said that the volunteering program SEP provides social interaction opportunities for students availability of volunteering program.[correct is Answer2]
    A3: There is a program encouraging volunteering among UM6P students, to work with associations, and do some social work, the initiative is called SEP, we count today more than 40 students who participated.[Argument FOR Answer2]
    A4: Another point is that the lack of opportunity is a chance for creation; communication is key.[correct is Answer3]
    A5: The absence of an opportunity is an opportunity in itself to be created UM6P offers many opportunities to students.[Argument FOR Answer3]
    A6: There are departments who their activity is to help students launch clubs, social initiatives, and start-ups....So maybe this is a lack of communication challenge rather than an absence of opportunities.[Argument AGAINST Answer3]


   - THEN CONVERT THE ARGUMENTS AND ANSWERS INTO THE FORMAT BELOW.
   -DO NOT ADD OR REMOVE ANY PART OF THE TEXT.
    -Based on the correctly Selected answer or answers for the Question  and their arguments which can FOR or AGAINST the chosen answer:, Output format must be print as model_answers_:
    model_answers_ =  [
    {{
        "answer": "Scientific/Financial/Hiring. Examples: to hire interns, a professor should not need to go through a lengthy process with HR.",
        "classification": "BARRIER",
        "arguments": [
            {{
                "text": "This will help to match the project with the right person in time without delay due to HR procedures.",
                "classification": "PRO"
            }},
            {{
                "text": "Paying small fees for conference registrations requires a lengthy process with Finance.",
                "classification": "PRO"
            }}
        ]
    }}
    ]

  -ENSURE THAT:
  -the answers are  classified as SOLUTION, BARRIER or METRICS.
  -the arguments are  classified as PRO or CON.PRO being the argument FOR the chosen answer while CON is the argument AGAINST the chosen answer
  -do not print format output
  -do not reprint the examples provided above

    """


    # Step 5: Get the response from the GPT model for classifying answers and arguments
    response_classification = client.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": "As a smart conversation tool, you work to learn from the examples provided,  strictly rely on the current text provided for the question based on the theme to print final output"},
            {"role": "user", "content": prompt_classification},
        ],
        max_tokens=1024,
        temperature=0,
        top_p=1.0,
        frequency_penalty=0,
        presence_penalty=0
    )

    # Step 6: Extract classification feedback
    classification_feedback = response_classification.choices[0].message.content.strip('\n')

    # Return the classified answers and arguments
    return classification_feedback


# Example usage
theme = "Research"
text ='''
User 1 said :

A better approach to methodology class. One of the problems is that way methodology is taught. The most boring way possible with no creativity way and lack of explaining the importance of the matter. It is key for researchers since the first years of their training to know the importance of it(This statement is particularly true in the case of social sciences).

'''

question = "How can we achieve success in research?"

result = analyze_and_classify(theme, text, question)
print(result)
# Out:
# model_answers_ = [
#     {
#         "answer": "A better approach to methodology class.",
#         "classification": "SOLUTION",
#         "arguments": [
#             {
#                 "text": "One of the problems is that way methodology is taught.",
#                 "classification": "PRO"
#             },
#             {
#                 "text": "The most boring way possible with no creativity way and lack of explaining the importance of the matter.",
#                 "classification": "PRO"
#             },
#             {
#                 "text": "It is key for researchers since the first years of their training to know the importance of it.",
#                 "classification": "PRO"
#             },
#             {
#                 "text": "This statement is particularly true in the case of social sciences.",
#                 "classification": "PRO"
#             }
#         ]
#     }
# ]
